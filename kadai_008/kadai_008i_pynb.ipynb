# %%
var=15

# %%
if var%3==0:
    print("Fizz")
# Out:
# Fizz

# %%
if var%5==0:
    print("Buzz")
# Out:
# Buzz

# %%
if var%3==0 and var%5==0:
    print("FizzBuzz")
elif var%3!=0 and var%5!=0:
    print(var)
# Out:
# FizzBuzz
