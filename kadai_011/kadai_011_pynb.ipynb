# %%
array = ["水","金","地","火","木","土","天","海","冥"]

# %%
for value in array:
    print(value)
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥

# %%
i = 0

while i < len(array):
    print(array[i])
    i += 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
